# %%
import pandas as pd

def create_records():

    student_data = {
        "RollNo": [201, 202, 203, 204, 205],
        "StudentName": ["Akhil", "Meghana", "Rohit", "Tejaswi", "Nithin"],
        "Department": ["CSE", "ECE", "EEE", "IT", "MECH"],
        "CGPA": [8.5, 9.1, 7.8, 8.9, 8.0],
        "Attendance": [92, 88, 75, 95, 81],
        "Hosteller": [True, False, True, True, False]
    }

    df = pd.DataFrame(student_data)

    df["StudentName"] = df["StudentName"].astype("string")
    df["Department"] = df["Department"].astype("string")

    return df


def main():

    df = create_records()

    print("\nComplete DataFrame:\n")
    print(df)

    print("\nColumn Data Types:\n")
    print(df.dtypes)

    numeric_columns = df.select_dtypes(include='number')

    print("\nNumeric Data:\n")
    print(numeric_columns)

    string_columns = df.select_dtypes(include='string')

    print("\nString Data:\n")
    print(string_columns)

    boolean_columns = df.select_dtypes(include='bool')

    print("\nBoolean Data:\n")
    print(boolean_columns)

    non_numeric_columns = df.select_dtypes(exclude='number')

    print("\nNon Numeric Data:\n")
    print(non_numeric_columns)


if __name__ == "__main__":
    main()
# Out:
# Complete DataFrame:
#
#    RollNo StudentName Department  CGPA  Attendance  Hosteller
# 0     201       Akhil        CSE   8.5          92       True
# 1     202     Meghana        ECE   9.1          88      False
# 2     203       Rohit        EEE   7.8          75       True
# 3     204     Tejaswi         IT   8.9          95       True
# 4     205      Nithin       MECH   8.0          81      False
#
# Column Data Types:
#
# RollNo                  int64
# StudentName    string[python]
# Department     string[python]
# CGPA                  float64
# Attendance              int64
# Hosteller                bool
# dtype: object
#
# Numeric Data:
#
#    RollNo  CGPA  Attendance
# 0     201   8.5          92
# 1     202   9.1          88
# 2     203   7.8          75
# 3     204   8.9          95
# 4     205   8.0          81
#
# String Data:
#
#   StudentName Department
# 0       Akhil        CSE
# 1     Meghana        ECE
# 2       Rohit        EEE
# 3     Tejaswi         IT
# ...
